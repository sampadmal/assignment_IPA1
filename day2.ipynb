# %%
i=1
while(i<=100):
    num=i
    while(num!=0):
        r=num%10
        num=num//10
        if(r==7):
            print(i)
            break
    i+=1
# Out:
# 7
# 17
# 27
# 37
# 47
# 57
# 67
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 87
# 97

# %%
num=int(input("enter a number"))
rev=0
n=num
while(n!=0):
    r=n%10
    rev=(rev*10)+r
    n=n//10
if(rev>num):
    print("reverse is greater")

# %%
n=int(input("enter a number"))
sum=0
while(True):
    while(n!=0):
        r=n%10
        sum+=r
        n=n//10
    n=sum
    sum=0
    if(n<10):
        print(n)
        break
# Out:
# 4

# %%
num=1459
even=0
odd=0
while(num!=0):
    r=num%10
    if(r%2==0):
        even=even+1
    else:
        odd=odd+1
    num=num//10
print("even number are ", even )
print("odd number are " ,odd)
# Out:
# even number are  1
# odd number are  3

# %%
num=int(input("enter a number"))
rev=0
n=num
while(n!=0):
    r=n%10
    rev=(rev*10)+r
    n=n//10
if(rev==num):
    print("palindrome number")
else:
    print("not a palindrome number")
# Out:
# not a palindrome number

# %%
num=77437
d=7
count=0
while(num!=0):
    r=num%10
    if(r==d):
        count=count+1
    num=num//10
print(count)
# Out:
# 3

# %%
sum=0
while(sum<=100):
    i=int(input("enter a number"))
    sum=sum+i
    if(sum>100):
        print("exceeded")
        break
# Out:
# exceeded

# %%
name='sampad'
passw=1234
count=1
user=input("enter your username")
if(user==name):
    while(count<=3):
        pw=int(input("enter your password"))
        if(pw==passw):
            print("successful")
            break
        else:
            count+=1

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
range(5)
# Out:
# range(0, 5)

# %%
print(print())
# Out:
# None

# %%
def add():
    a=int(input("enter a"))
    b=int(input("enter b"))
    return a+b
add()
# Out:
# 23

# %%
def even_odd(num ,d):
    count=0
    while(num!=0):
        r=num%10
        if(r==d):
            count=count+1
        num=num//10
    print(count)
even_odd(467727,7)
# Out:
# 3

# %%
def palindrome(num):
    rev=0
    n=num
    while(n!=0):
        r=n%10
        rev=(rev*10)+r
        n=n//10
    if(rev==num):
        print("palindrome number")
    else:
        print("not a palindrome number")
palindrome(12321)
# Out:
# palindrome number

# %%
def greet (name='sampad',clg='hit'):
    print(clg,name)
greet(name='mal')
# Out:
# hit mal

# %%
def info(roll,name='sampad',age=22):
    print(name,age,roll)
info(144)
# Out:
# sampad 22 144

# %%
# import list tuple and dictnory 
from typing import List
num: List[int]=[1,2,3,4,5]
t: tuple[int]=(1,2,3,4,5)
d: dict[int,str]={1:'sampad',2:'rohan'}
num
t
dict
# Out:
# {1: 'sampad', 2: 'rohan'}

# %%
import logging
logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(lineno)d -%(levelname)s - %(message)s",
    filemode='a'    
)
balance=10000
n=int(input("enter money you want to withdraw"))
if(n<balance):
    logging.info("withdrawal successful")
else:
    logging.error("balance is lower")

# %%
import logging
logging.basicConfig(
    filename="vowel.log",
    level=logging.INFO,
    format="%(asctime)s - %(lineno)d -%(levelname)s - %(message)s",
    filemode='a'    
)
def vowel_count(c:str) -> int:
    '''count vowel number in string
    Parameters:
        c(str):Input string
    Returns:
        int:total numbers of vowels in the string

    '''
    logging.info("counting no of vowels in the string")
    count=0
    for i in c:
        if i in ['a','e','i','o','u']:
            count+=1
    logging.info(f"vowel count calculated :{count}")
    return count
vowel_count('sampad')
# Out:
# 2

# %%
import logging
logging.basicConfig(
    filename="freq.log",
    level=logging.INFO,
    format="%(asctime)s - %(lineno)d -%(levelname)s - %(message)s",
    filemode='a'    
)
def frequency(c:str) -> int : 
    '''counting frequency of a character in a string
       Parameters:
            c(str):Input string
       Returns:
            int:frequency of the character
    '''
    logging.info("frequency of characters  in the string")
    freq={}
    for i in c:
        if i in freq:
            freq[i]+=1
        else:
            freq[i]=1
    return freq
f=frequency('sampad')
logging.info(f)

# %%
import logging
logging.basicConfig(
    filename="sec.log",
    level=logging.INFO,
    format="%(asctime)s - %(lineno)d -%(levelname)s - %(message)s",
    filemode='a'    
)
def sec_lar(l:list) -> int:
    '''finding second largest element in a list
    Parameters:
        l(list): input list
    Returns:
        int: Second largest character
    '''
    logging.info("Second largest character in the list")
    a=float('-inf')
    b=float('-inf')
    for i in l:
        if i>a:
            b=a
            a=i
        if i>b and i!=a:
            b=i
    return b
num=[1,2,3,4,5,6]
s=sec_lar(num)
logging.info(s)

# %%
import logging
logging.basicConfig(
    filename="sorting.log",
    level=logging.INFO,
    format="%(asctime)s - %(lineno)d -%(levelname)s - %(message)s",
    filemode='a'    
)
def sorting(l:list) -> int:
    '''list sorted or not 
    Parameters:
        l(list):input list
    Result:
        bool:gives true or false value
    '''
    logging.info("checking a list is sorted or not")
    s=sorted(l)
    if(s==l):
        logging.info("list is sorted in ascending order")
        return True
    else:
        logging.info("list is not sorted in ascending order")
        return False
ls=[1,2,3,4,5]
result=sorting(ls)
logging.info(result)

# %%
inp='python is very very easy language'
print([(i.lower(),len(i)) for i in inp.split()])
# Out:
# [('python', 6), ('is', 2), ('very', 4), ('very', 4), ('easy', 4), ('language', 8)]

# %%
word='Hai HeLLO'
print([{ ch: ord(ch) for ch in word if ch.isupper()}])
# Out:
# [{'H': 72, 'L': 76, 'O': 79}]
